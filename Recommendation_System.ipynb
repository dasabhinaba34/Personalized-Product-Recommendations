# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# Read data from the CSV file
df = pd.read_csv('data.csv')

# Ensure product_id values are unique
df = df.drop_duplicates(subset=['user_id', 'product_id'])

# Convert categorical variables to numerical values
df['search_history'] = df['search_history'].astype('category').cat.codes
df['browse_history'] = df['browse_history'].astype('category').cat.codes
df['occupation'] = df['occupation'].astype('category').cat.codes

# Creating a user-item matrix
user_item_matrix = df.pivot(index='user_id', columns='product_id', values='product_rating').fillna(0)

# Calculate cosine similarity between products
product_similarity = cosine_similarity(user_item_matrix.T)

# Define a function to get product recommendations
def get_recommendations(user_id, num_recommendations=2):
    user_ratings = user_item_matrix.loc[user_id]
    similar_scores = product_similarity.dot(user_ratings)

    user_searches = df[df['user_id'] == user_id].set_index('product_id')['num_searches']
    user_salary = df[df['user_id'] == user_id]['salary'].values[0]

    # Calculate weighted scores based on number of searches and salary
    weighted_scores = []
    for idx in range(len(user_item_matrix.columns)):
        product_id = user_item_matrix.columns[idx]
        product_score = similar_scores[idx] * user_searches.get(product_id, 0) + user_salary
        weighted_scores.append(product_score)

    recommended_product_indices = np.argsort(weighted_scores)[-num_recommendations:]
    recommended_products = [df.loc[df['product_id'] == user_item_matrix.columns[idx], 'product_name'].values[0] for idx in recommended_product_indices]
    return recommended_products

import time
from tabulate import tabulate

# Take input for the number of recommendations for all users
num_recommendations = int(input("Enter the number of recommendations for all users: "))

# Display a loading message for 2-3 seconds
print("Loading...")
time.sleep(2)  # Sleep for 2 seconds

# Create a list to store user recommendations
user_recommendations = []

# Test the recommender system for all users starting from user_id 1001
for user_id in range(1001, 1001 + len(user_item_matrix)):
    recommendations = get_recommendations(user_id, num_recommendations)
    username = df[df['user_id'] == user_id]['username'].values[0]  # Get the username from the data
    recommended_products = ', '.join(recommendations)  # Join recommended products with a comma
    user_recommendations.append([username, recommended_products])

# Print the table with headers
headers = ["Username", "Recommended Products"]
print(tabulate(user_recommendations, headers, tablefmt="fancy_grid"))
# Out:
# Loading...
# ╒════════════╤════════════════════════════════════════════════════╕
# │ Username   │ Recommended Products                               │
# ╞════════════╪════════════════════════════════════════════════════╡
# │ user1      │ Sunglasses, Phone, Tablet, Laptop, Headphones      │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user2      │ Desk, Chair, Notebook, Pen, Book                   │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user3      │ Tablet, Headphones, Watch, Phone, Laptop           │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user4      │ Keyboard, Printer, Monitor, Tablet, Phone          │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user5      │ Hat, Phone, Umbrella, Shirt, Water Bottle          │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user6      │ Tablet, Headphones, Watch, Phone, Laptop           │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user7      │ Chair, Desk, Table, Laptop, Phone                  │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user8      │ Monitor, Printer, Keyboard, Mouse, Tablet          │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user9      │ Pen, Notebook, Backpack, Shoes, Water Bottle       │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user10     │ Desk, Table, Printer, Keyboard, Mouse              │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user11     │ Backpack, Tablet, Sneakers, Water Bottle, Umbrella │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user12     │ Tablet, Keyboard, Mouse, Monitor, Printer          │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user13     │ Backpack, Tablet, Sneakers, Water Bottle, Umbrella │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user14     │ Tablet, Keyboard, Mouse, Monitor, Printer          │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user15     │ Backpack, Tablet, Sneakers, Water Bottle, Umbrella │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user16     │ Tablet, Keyboard, Mouse, Monitor, Printer          │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user17     │ Backpack, Tablet, Sneakers, Water Bottle, Umbrella │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user18     │ Tablet, Keyboard, Mouse, Monitor, Printer          │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user19     │ Backpack, Tablet, Sneakers, Water Bottle, Umbrella │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user20     │ Tablet, Keyboard, Mouse, Monitor, Printer          │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user21     │ Backpack, Tablet, Sneakers, Water Bottle, Umbrella │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user22     │ Tablet, Keyboard, Mouse, Monitor, Printer          │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user23     │ Backpack, Tablet, Sneakers, Water Bottle, Umbrella │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user24     │ Tablet, Keyboard, Mouse, Monitor, Printer          │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user25     │ Backpack, Tablet, Sneakers, Water Bottle, Umbrella │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user26     │ Tablet, Keyboard, Mouse, Monitor, Printer          │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user27     │ Backpack, Tablet, Sneakers, Water Bottle, Umbrella │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user28     │ Tablet, Keyboard, Mouse, Monitor, Printer          │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user29     │ Backpack, Tablet, Sneakers, Water Bottle, Umbrella │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user30     │ Tablet, Keyboard, Mouse, Monitor, Printer          │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user31     │ Backpack, Tablet, Sneakers, Water Bottle, Umbrella │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user32     │ Tablet, Keyboard, Mouse, Monitor, Printer          │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user33     │ Backpack, Tablet, Sneakers, Water Bottle, Umbrella │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user34     │ Tablet, Keyboard, Mouse, Monitor, Printer          │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user35     │ Backpack, Tablet, Sneakers, Water Bottle, Umbrella │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user36     │ Tablet, Keyboard, Mouse, Monitor, Printer          │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user37     │ Backpack, Tablet, Sneakers, Water Bottle, Umbrella │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user38     │ Tablet, Keyboard, Mouse, Monitor, Printer          │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user39     │ Backpack, Tablet, Sneakers, Water Bottle, Umbrella │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user40     │ Tablet, Keyboard, Mouse, Monitor, Printer          │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user41     │ Backpack, Tablet, Sneakers, Water Bottle, Umbrella │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user42     │ Tablet, Keyboard, Mouse, Monitor, Printer          │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user43     │ Backpack, Tablet, Sneakers, Water Bottle, Umbrella │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user44     │ Tablet, Keyboard, Mouse, Monitor, Printer          │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user45     │ Backpack, Tablet, Sneakers, Water Bottle, Umbrella │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user46     │ Tablet, Keyboard, Mouse, Monitor, Printer          │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user47     │ Backpack, Tablet, Sneakers, Water Bottle, Umbrella │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user48     │ Tablet, Keyboard, Mouse, Monitor, Printer          │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user49     │ Backpack, Tablet, Sneakers, Water Bottle, Umbrella │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user50     │ Tablet, Keyboard, Mouse, Monitor, Printer          │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user51     │ Backpack, Tablet, Sneakers, Water Bottle, Umbrella │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user52     │ Tablet, Keyboard, Mouse, Monitor, Printer          │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user53     │ Backpack, Tablet, Sneakers, Water Bottle, Umbrella │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user54     │ Tablet, Keyboard, Mouse, Monitor, Printer          │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user55     │ Backpack, Tablet, Sneakers, Water Bottle, Umbrella │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user56     │ Tablet, Keyboard, Mouse, Monitor, Printer          │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user57     │ Backpack, Tablet, Sneakers, Water Bottle, Umbrella │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user58     │ Tablet, Keyboard, Mouse, Monitor, Printer          │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user59     │ Backpack, Tablet, Sneakers, Water Bottle, Umbrella │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user60     │ Tablet, Keyboard, Mouse, Monitor, Printer          │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user61     │ Backpack, Tablet, Sneakers, Water Bottle, Umbrella │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user62     │ Tablet, Keyboard, Mouse, Monitor, Printer          │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user63     │ Backpack, Tablet, Sneakers, Water Bottle, Umbrella │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user64     │ Tablet, Keyboard, Mouse, Monitor, Printer          │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user65     │ Backpack, Tablet, Sneakers, Water Bottle, Umbrella │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user66     │ Tablet, Keyboard, Mouse, Monitor, Printer          │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user67     │ Backpack, Tablet, Sneakers, Water Bottle, Umbrella │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user68     │ Tablet, Keyboard, Mouse, Monitor, Printer          │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user69     │ Backpack, Tablet, Sneakers, Water Bottle, Umbrella │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user70     │ Tablet, Keyboard, Mouse, Monitor, Printer          │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user71     │ Backpack, Tablet, Sneakers, Water Bottle, Umbrella │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user72     │ Tablet, Keyboard, Mouse, Monitor, Printer          │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user73     │ Backpack, Tablet, Sneakers, Water Bottle, Umbrella │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user74     │ Tablet, Keyboard, Mouse, Monitor, Printer          │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user75     │ Backpack, Tablet, Sneakers, Water Bottle, Umbrella │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user76     │ Tablet, Keyboard, Mouse, Monitor, Printer          │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user77     │ Backpack, Tablet, Sneakers, Water Bottle, Umbrella │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user78     │ Tablet, Keyboard, Mouse, Monitor, Printer          │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user79     │ Backpack, Tablet, Sneakers, Water Bottle, Umbrella │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user80     │ Tablet, Keyboard, Mouse, Monitor, Printer          │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user81     │ Backpack, Tablet, Sneakers, Water Bottle, Umbrella │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user82     │ Tablet, Keyboard, Mouse, Monitor, Printer          │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user83     │ Backpack, Tablet, Sneakers, Water Bottle, Umbrella │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user84     │ Tablet, Keyboard, Mouse, Monitor, Printer          │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user85     │ Backpack, Tablet, Sneakers, Water Bottle, Umbrella │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user86     │ Tablet, Keyboard, Mouse, Monitor, Printer          │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user87     │ Backpack, Tablet, Sneakers, Water Bottle, Umbrella │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user88     │ Tablet, Keyboard, Mouse, Monitor, Printer          │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user89     │ Backpack, Tablet, Sneakers, Water Bottle, Umbrella │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user90     │ Tablet, Keyboard, Mouse, Monitor, Printer          │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user91     │ Backpack, Tablet, Sneakers, Water Bottle, Umbrella │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user92     │ Tablet, Keyboard, Mouse, Monitor, Printer          │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user93     │ Backpack, Tablet, Sneakers, Water Bottle, Umbrella │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user94     │ Tablet, Keyboard, Mouse, Monitor, Printer          │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user95     │ Backpack, Tablet, Sneakers, Water Bottle, Umbrella │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user96     │ Tablet, Keyboard, Mouse, Monitor, Printer          │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user97     │ Backpack, Tablet, Sneakers, Water Bottle, Umbrella │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user98     │ Tablet, Keyboard, Mouse, Monitor, Printer          │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user99     │ Backpack, Tablet, Sneakers, Water Bottle, Umbrella │
# ├────────────┼────────────────────────────────────────────────────┤
# │ user100    │ Tablet, Keyboard, Mouse, Monitor, Printer          │
# ╘════════════╧════════════════════════════════════════════════════╛

# %%
# Initialize variables for evaluation
total_users = len(user_item_matrix)
correct_recommendations = 0
total_recommendations = 0  # Track the total number of recommendations made

# Evaluate the model for all users
for user_id in range(1001, 1001 + total_users):  # Start from user_id 1001
    recommendations = get_recommendations(user_id, num_recommendations=2)

    # Get the actual products that the user has interacted with
    actual_interactions = df[(df['user_id'] == user_id) & (df['product_rating'] > 0)]['product_name'].tolist()

    # Calculate the number of correct recommendations
    for product in recommendations:
        total_recommendations += 1
        if product in actual_interactions:
            correct_recommendations += 1

# Calculate accuracy
accuracy = correct_recommendations / total_recommendations  # Total correct recommendations divided by total recommendations made
print(f"Model Accuracy: {accuracy * 100:.2f}%")
# Out:
# Model Accuracy: 100.00%
